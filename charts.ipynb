# %%
import pandas as pd
import matplotlib.pyplot as plt

a1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/500/results_stats.csv')["95%"].to_list()[-1]
a2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/750/results_stats.csv')["95%"].to_list()[-1]
a3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/1000/results_stats.csv')["95%"].to_list()[-1]
a4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/1250/results_stats.csv')["95%"].to_list()[-1]
a5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/1500/results_stats.csv')["95%"].to_list()[-1]
a6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/1750/results_stats.csv')["95%"].to_list()[-1]
a7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/2000/results_stats.csv')["95%"].to_list()[-1]
a8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb1/2250/results_stats.csv')["95%"].to_list()[-1]

b1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/500/results_stats.csv')["95%"].to_list()[-1]
b2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/750/results_stats.csv')["95%"].to_list()[-1]
b3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/1000/results_stats.csv')["95%"].to_list()[-1]
b4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/1250/results_stats.csv')["95%"].to_list()[-1]
b5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/1500/results_stats.csv')["95%"].to_list()[-1]
b6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/1750/results_stats.csv')["95%"].to_list()[-1]
b7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/2000/results_stats.csv')["95%"].to_list()[-1]
b8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb2/2250/results_stats.csv')["95%"].to_list()[-1]

c1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/500/results_stats.csv')["95%"].to_list()[-1]
c2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/750/results_stats.csv')["95%"].to_list()[-1]
c3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/1000/results_stats.csv')["95%"].to_list()[-1]
c4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/1250/results_stats.csv')["95%"].to_list()[-1]
c5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/1500/results_stats.csv')["95%"].to_list()[-1]
c6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/1750/results_stats.csv')["95%"].to_list()[-1]
c7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/2000/results_stats.csv')["95%"].to_list()[-1]
c8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/distributed/2250/results_stats.csv')["95%"].to_list()[-1]

d1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/500/results_stats.csv')["95%"].to_list()[-1]
d2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/750/results_stats.csv')["95%"].to_list()[-1]
d3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/1000/results_stats.csv')["95%"].to_list()[-1]
d4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/1250/results_stats.csv')["95%"].to_list()[-1]
d5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/1500/results_stats.csv')["95%"].to_list()[-1]
d6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/1750/results_stats.csv')["95%"].to_list()[-1]
d7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/2000/results_stats.csv')["95%"].to_list()[-1]
d8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb1/2250/results_stats.csv')["95%"].to_list()[-1]

e1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/500/results_stats.csv')["95%"].to_list()[-1]
e2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/750/results_stats.csv')["95%"].to_list()[-1]
e3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/1000/results_stats.csv')["95%"].to_list()[-1]
e4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/1250/results_stats.csv')["95%"].to_list()[-1]
e5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/1500/results_stats.csv')["95%"].to_list()[-1]
e6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/1750/results_stats.csv')["95%"].to_list()[-1]
e7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/2000/results_stats.csv')["95%"].to_list()[-1]
e8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb2/2250/results_stats.csv')["95%"].to_list()[-1]

# f1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/500/results_stats.csv')["95%"].to_list()[-1]
# f2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/750/results_stats.csv')["95%"].to_list()[-1]
# f3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1000/results_stats.csv')["95%"].to_list()[-1]
# f4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1250/results_stats.csv')["95%"].to_list()[-1]
# f5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1500/results_stats.csv')["95%"].to_list()[-1]
# f6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1750/results_stats.csv')["95%"].to_list()[-1]
# f7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/2000/results_stats.csv')["95%"].to_list()[-1]
# f8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/2250/results_stats.csv')["95%"].to_list()[-1]

f1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/500/results_stats.csv')["95%"].to_list()[-1]
f2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/750/results_stats.csv')["95%"].to_list()[-1]
f3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1000/results_stats.csv')["95%"].to_list()[-1]
f4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1250/results_stats.csv')["95%"].to_list()[-1]
f5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1500/results_stats.csv')["95%"].to_list()[-1]
f6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/1750/results_stats.csv')["95%"].to_list()[-1]
f7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/2000/results_stats.csv')["95%"].to_list()[-1]
# f8 = pd.read_csv('~/new_tests/locust/2250/results_stats.csv')["95%"].to_list()[-1]
f8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/desacoplado/2250/results_stats.csv')["95%"].to_list()[-1]

g1 = pd.read_csv('~/new_tests/monolithic/500/results_stats.csv')["95%"].to_list()[-1]
g2 = pd.read_csv('~/new_tests/monolithic/750/results_stats.csv')["95%"].to_list()[-1]
g3 = pd.read_csv('~/new_tests/monolithic/1000/results_stats.csv')["95%"].to_list()[-1]
g4 = pd.read_csv('~/new_tests/monolithic/1250/results_stats.csv')["95%"].to_list()[-1]
g5 = pd.read_csv('~/new_tests/monolithic/1500/results_stats.csv')["95%"].to_list()[-1]
g6 = pd.read_csv('~/new_tests/monolithic/1750/results_stats.csv')["95%"].to_list()[-1]
g7 = pd.read_csv('~/new_tests/monolithic/2000/results_stats.csv')["95%"].to_list()[-1]
g8 = pd.read_csv('~/new_tests/monolithic/2250/results_stats.csv')["95%"].to_list()[-1]

# Frontend isolado com acoplamento dos outros serviços - 01 máquinas virtuais
h1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/500/results_stats.csv')["95%"].to_list()[-1]
h2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/750/results_stats.csv')["95%"].to_list()[-1]
h3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/1000/results_stats.csv')["95%"].to_list()[-1]
h4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/1250/results_stats.csv')["95%"].to_list()[-1]
h5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/1500/results_stats.csv')["95%"].to_list()[-1]
h6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/1750/results_stats.csv')["95%"].to_list()[-1]
h7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/2000/results_stats.csv')["95%"].to_list()[-1]
h8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb3/2250/results_stats.csv')["95%"].to_list()[-1]

# Frontend isolado com acoplamento dos outros serviços - 02 máquinas virtuais
i1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/500/results_stats.csv')["95%"].to_list()[-1]
i2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/750/results_stats.csv')["95%"].to_list()[-1]
i3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/1000/results_stats.csv')["95%"].to_list()[-1]
i4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/1250/results_stats.csv')["95%"].to_list()[-1]
i5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/1500/results_stats.csv')["95%"].to_list()[-1]
i6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/1750/results_stats.csv')["95%"].to_list()[-1]
i7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/2000/results_stats.csv')["95%"].to_list()[-1]
i8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb3/2250/results_stats.csv')["95%"].to_list()[-1]

# ProductService isolado sem acoplamento dos os outros serviços - 02 máquinas virtuais
j1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/500/results_stats.csv')["95%"].to_list()[-1]
j2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/750/results_stats.csv')["95%"].to_list()[-1]
j3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/1000/results_stats.csv')["95%"].to_list()[-1]
j4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/1250/results_stats.csv')["95%"].to_list()[-1]
j5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/1500/results_stats.csv')["95%"].to_list()[-1]
j6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/1750/results_stats.csv')["95%"].to_list()[-1]
j7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/2000/results_stats.csv')["95%"].to_list()[-1]
j8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb4/2250/results_stats.csv')["95%"].to_list()[-1]

# grupo frontend acoplado, resto desacoplado - 01 VM
k1 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/500/results_stats.csv')["95%"].to_list()[-1]
k2 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/750/results_stats.csv')["95%"].to_list()[-1]
k3 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/1000/results_stats.csv')["95%"].to_list()[-1]
k4 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/1250/results_stats.csv')["95%"].to_list()[-1]
k5 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/1500/results_stats.csv')["95%"].to_list()[-1]
k6 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/1750/results_stats.csv')["95%"].to_list()[-1]
k7 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/2000/results_stats.csv')["95%"].to_list()[-1]
k8 = pd.read_csv('~/new_tests/vm_coupled/4gb_4cpu/comb5/2250/results_stats.csv')["95%"].to_list()[-1]

# grupo frontend acoplado, resto desacoplado - 02 VM
l1 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/500/results_stats.csv')["95%"].to_list()[-1]
l2 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/750/results_stats.csv')["95%"].to_list()[-1]
l3 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/1000/results_stats.csv')["95%"].to_list()[-1]
l4 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/1250/results_stats.csv')["95%"].to_list()[-1]
l5 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/1500/results_stats.csv')["95%"].to_list()[-1]
l6 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/1750/results_stats.csv')["95%"].to_list()[-1]
l7 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/2000/results_stats.csv')["95%"].to_list()[-1]
l8 = pd.read_csv('~/new_tests/vm_distributed/2_nodes_4gb_4cpu/comb5/2250/results_stats.csv')["95%"].to_list()[-1]



# z1 = pd.read_csv('~/new_tests/locust/500/results_stats.csv')["95%"].to_list()[-1]
# z2 = pd.read_csv('~/new_tests/locust/750/results_stats.csv')["95%"].to_list()[-1]
# z3 = pd.read_csv('~/new_tests/locust/1000/results_stats.csv')["95%"].to_list()[-1]
# z4 = pd.read_csv('~/new_tests/locust/1250/results_stats.csv')["95%"].to_list()[-1]
# z5 = pd.read_csv('~/new_tests/locust/1500/results_stats.csv')["95%"].to_list()[-1]
# z6 = pd.read_csv('~/new_tests/locust/1750/results_stats.csv')["95%"].to_list()[-1]
# z7 = pd.read_csv('~/new_tests/locust/2000/results_stats.csv')["95%"].to_list()[-1]
# z8 = pd.read_csv('~/new_tests/locust/2250/results_stats.csv')["95%"].to_list()[-1]

# %%
df = pd.DataFrame({
    # 'Frontend isolado sem acoplamento dos outros serviços - 02 máquinas virtuais': [c1, c2, c3, c4, c5, c6, c7, c8],
    'Configuração 2 - 02 Máquinas virtuais': [b1, b2, b3, b4, b5, b6, b7, b8],
    # "Frontend isolado com acoplamento dos outros serviços - 02 máquinas virtuais" : [i1, i2, i3, i4, i5, i6, i7, i8],
    # 'Configuração 1 - 02 Máquinas virtuais': [a1, a2, a3, a4, a5, a6, a7, a8],
    'Configuração 2 - 01 Máquina virtual': [e1, e2, e3, e4, e5, e6, e7, e8],
    # 'Configuração 1 - 01 Máquina virtual': [d1, d2, d3, d4, d5, d6, d7, d8],
    # 'Main isolado sem acoplamento - 01 Máquina virtual': [f1, f2, f3, f4, f5, f6, f7, f8],
    # "Serviço monolítico" : [g1, g2, g3, g4, g5, g6, g7, g8],
    # "Frontend isolado - uma VM" : [h1, h2, h3, h4, h5, h6, h7, h8],
    # "ProductService isolado sem acoplamento dos os outros serviços - 02 máquinas virtuais" : [j1, j2, j3, j4, j5, j6, j7, j8],
    # "grupo frontend acoplado, resto desacoplado - 01 VM " : [k1, k2, k3, k4, k5, k6, k7, k8],
    # "grupo frontend acoplado, resto desacoplado - 02 VM " : [l1, l2, l3, l4, l5, l6, l7, l8],
    # "Novo Teste" : [z1, z2, z3, z4, z5, z6, z7, z8],
}, index=[500, 750, 1000, 1250, 1500, 1750, 2000, 2250])
# }, index=[1500, 2000, 2500, 3000, 3500,4000, 4500, 5000, 5500, 6000])
# }, index=[1500, 2000, 2500, 3000, 3500,4000])
# df.plot.bar(ylabel="Aggregated Response Time (ms)", xlabel=" Quantidade de Usuários")
df.plot.bar(ylabel="Tempo agregado (ms), percentil 95", xlabel=" Quantidade de Usuários")
# Out:
# <Axes: xlabel=' Quantidade de Usuários', ylabel='Tempo agregado (ms), percentil 95'>

# %%
# combined_df = combined_df[['Name', 'Average Response Time_1', 'Average Response Time_2']]
combined_df = combined_df[['Name', 'Serviço Distribuído', 'Serviço Monolítico']]
combined_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # combined_df = combined_df[['Name', 'Average Response Time_1', 'Average Response Time_2']]
# ----> <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> combined_df = combined_df[['Name', 'Serviço Distribuído', 'Serviço Monolítico']]
#       <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> combined_df
#
# NameError: name 'combined_df' is not defined

# %%
combined_df = combined_df.iloc[:, 1:]
combined_df = combined_df.iloc[1:, :]
combined_df
# Out:
#                    Name  Serviço Distribuído  Serviço Monolítico
# 1                 /cart          4250.383445         4382.913015
# 2                 /cart          8605.591951         8939.343235
# 3        /cart/checkout          4285.133478         4568.737564
# 4   /images/loafers.jpg          4337.275997         4536.320248
# 5   /product/0PUK6V6EV0          4236.465668         4387.907342
# 6   /product/1YMWWN1N4O          4255.864592         4379.731352
# 7   /product/2ZYFJ3GM2N          4229.173537         4396.812737
# 8   /product/66VCHSJNUP          4251.184734         4362.039377
# 9   /product/6E92ZMYYFZ          4242.032151         4337.347368
# 10  /product/9SIQT8TOJO          4246.462887         4347.083169
# 11  /product/L9ECAV7KIM          4228.102881         4381.230009
# 12  /product/LS4PSXUNUM          4258.935895         4391.521152
# 13  /product/OLJCESPC7Z          4233.311963         4374.330986
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

melted_df = pd.melt(combined_df, id_vars=['Name'], value_vars=['Serviço Distribuído', 'Serviço Monolítico'], var_name='Coleta', value_name='Tempo')

plt.figure(figsize=(10, 6))
colors = ['g', 'b']
bar_width = 0.2
index = np.arange(len(melted_df['Name'].unique())+1)


# for i, coleta in enumerate(melted_df['Coleta'].unique()):
#     subset = melted_df[melted_df['Coleta'] == coleta]
#     print(subset['Tempo'])
#     plt.bar(index + i* bar_width, subset['Tempo'], width=bar_width, label=coleta, color=colors[i])

# plt.xlabel('Requisição')
# plt.ylabel('Tempo médio de resposta (milisegundos)')
# plt.title('Tempo médio de resposta, 5000 usuários, limitação de 0.5 CPU')
# plt.xticks(np.arange(14), labels=melted_df['Name'].unique(), rotation=45)
# plt.legend(title='Serviço')


# plt.tight_layout()
# plt.show()
# combined_df.set_index(melted_df["Name"].unique())
# combined_df.plot.bar()
combined_df.plot.bar(x="Name")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/home/ricardo/Documents/tcc/onlineboutique/autoTest/charts/users.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> melted_df = pd.melt(combined_df, id_vars=['Name'], value_vars=['Serviço Distribuído', 'Serviço Monolítico'], var_name='Coleta', value_name='Tempo')
# ...
